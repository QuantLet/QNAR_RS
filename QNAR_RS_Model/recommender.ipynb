# %%
import recbole
from recbole.model.abstract_recommender import SequentialRecommender

import sys
sys.path.insert(0, "..")
from shared.GNNModel import GNNModel

# %% [markdown]
# <h1>Good Papers to cite in Lit Review (and to better)</h1>
#
# https://arxiv.org/abs/1511.06939
#
# https://arxiv.org/abs/1706.03847

# %%
from recbole.quick_start import run_recbole
run_recbole(model='GRU4Rec', dataset='twitch-100k', config_file_list=['gru4rec_test.yaml'])
# Out:
# 23 Jan 14:37    INFO  ['/opt/anaconda3/envs/xai/lib/python3.12/site-packages/ipykernel_launcher.py', '-f', '/Users/raulbag/Library/Jupyter/runtime/kernel-0882eac0-14c6-4d04-a672-600e4b6f4c41.json']
# 23 Jan 14:37    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/twitch-100k
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 500
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 10
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size = 128
# num_layers = 1
# dropout_prob = 0.3
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 23 Jan 14:37    INFO  Prepare to download dataset [twitch-100k] from [https://recbole.s3-accelerate.amazonaws.com/ProcessedDatasets/Twitch/Twitch-100k/Twitch-100k.zip].
# 23 Jan 14:37    INFO  Downloading https://recbole.s3-accelerate.amazonaws.com/ProcessedDatasets/Twitch/Twitch-100k/Twitch-100k.zip
# Downloaded 0.04 GB: 100%|██████████| 44/44 [00:02<00:00, 19.37it/s]
# 23 Jan 14:37    INFO  Extracting dataset/twitch-100k/Twitch-100k.zip
# 23 Jan 14:37    WARNING  Moving downloaded file with suffix [].
# 23 Jan 14:37    INFO  Downloading done.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from recbole.quick_start import run_recbole
# ----> 2 run_recbole(model='GRU4Rec', dataset='twitch-100k', config_file_list=['gru4rec_test.yaml'])
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/quick_start/quick_start.py:129, in run_recbole(model, dataset, config_file_list, config_dict, saved, queue)
#     126 logger.info(config)
#     128 # dataset filtering
# --> 129 dataset = create_dataset(config)
#     130 logger.info(dataset)
#     132 # dataset splitting
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/utils.py:72, in create_dataset(config)
#      69         logger.info(set_color("Load filtered dataset from", "pink") + f": [{file}]")
#      70         return dataset
# ---> 72 dataset = dataset_class(config)
#      73 if config["save_dataset"]:
#      74     dataset.save()
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/dataset/sequential_dataset.py:36, in SequentialDataset.__init__(self, config)
#      34 self.max_item_list_len = config["MAX_ITEM_LIST_LENGTH"]
#      35 self.item_list_length_field = config["ITEM_LIST_LENGTH_FIELD"]
# ---> 36 super().__init__(config)
#      37 if config["benchmark_filename"] is not None:
#      38     self._benchmark_presets()
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/dataset/dataset.py:108, in Dataset.__init__(self, config)
#     106 self.dataset_name = config["dataset"]
#     107 self.logger = getLogger()
# --> 108 self._from_scratch()
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/dataset/dataset.py:118, in Dataset._from_scratch(self)
#     116 self._get_preset()
#     117 self._get_field_from_config()
# --> 118 self._load_data(self.dataset_name, self.dataset_path)
#     119 self._init_alias()
#     120 self._data_processing()
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/dataset/dataset.py:267, in Dataset._load_data(self, token, dataset_path)
#     257 """Load features.
#     258
#     259 Firstly load interaction features, then user/item features optionally,
#    (...)
#     264     dataset_path (str): path of dataset dir.
#     265 """
#     266 if not os.path.exists(dataset_path):
# --> 267     self._download()
#     268 self._load_inter_feat(token, dataset_path)
#     269 self.user_feat = self._load_user_or_item_feat(
#     270     token, dataset_path, FeatureSource.USER, "uid_field"
#     271 )
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/recbole/data/dataset/dataset.py:252, in Dataset._download(self)
#     250         self.logger.info("Stop download.")
#     251         exit(-1)
# --> 252     torch.distributed.barrier()
#     253 else:
#     254     torch.distributed.barrier()
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/torch/distributed/c10d_logger.py:83, in _exception_logger.<locals>.wrapper(*args, **kwargs)
#      80 @functools.wraps(func)
#      81 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> _T:
#      82     try:
# ---> 83         return func(*args, **kwargs)
#      84     except Exception as error:
#      85         msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py:4149, in barrier(group, async_op, device_ids)
#    4146     return
#    4148 opts = BarrierOptions()
# -> 4149 opts.device = _get_pg_default_device(group)
#    4150 if device_ids is not None:
#    4151     if isinstance(device_ids, list):
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py:771, in _get_pg_default_device(group)
#     752 def _get_pg_default_device(group: Optional[ProcessGroup] = None) -> torch.device:
#     753     """
#     754     Return the device to use with ``group`` for control flow usage (object collectives, barrier).
#     755
#    (...)
#     769
#     770     """
# --> 771     group = group or _get_default_group()
#     772     if group in _world.pg_default_device:
#     773         # Previously searched and cached; just return
#     774         return _world.pg_default_device[group]
#
# File /opt/anaconda3/envs/xai/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py:1150, in _get_default_group()
#    1148 """Get the default process group created by init_process_group."""
#    1149 if not is_initialized():
# -> 1150     raise ValueError(
#    1151         "Default process group has not been initialized, "
#    1152         "please make sure to call init_process_group."
#    1153     )
#    1154 if TYPE_CHECKING:
#    1155     return not_none(GroupMember.WORLD)
#
# ValueError: Default process group has not been initialized, please make sure to call init_process_group.
